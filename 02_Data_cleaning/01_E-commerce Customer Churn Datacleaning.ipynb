# %%
# importing libraries
import pandas as pd
import numpy as np

# %%
# loading dataset
df = pd.read_excel('E-commerce Customer Churn Dataset_Raw_Data.xlsx')

# %%
df.head()
# Out:
#   Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0       C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 1       C1001       Rohit Kumar    Male   NaN        Delhi      Noida
# 2       C1002       Pooja Singh  Female  42.0           UP     Kanpur
# 3       C1003               NaN    Male  59.0    Karnataka  Bengaluru
# 4       C1004       Mohit Arora   male   26.0      Gujarat  Ahmedabad
#
#    Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0           58.0             basic          1614.26       93273.08
# 1           36.0           Premium           429.60       15858.60
# 2           13.0             Basic           555.03        6869.39
# 3           55.0          Standard              NaN      101349.10
# 4            6.0           Premium           314.02        1926.12
#
#     Contract_Type Payment_Method Internet_Service Tech_Support Senior_Citizen  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            542 non-null    object
#  1   Customer_Name          533 non-null    object
#  2   Gender                 536 non-null    object
#  3   Age                    536 non-null    float64
#  4   State                  531 non-null    object
#  5   City                   539 non-null    object
#  6   Tenure_Months          534 non-null    float64
#  7   Subscription_Type      530 non-null    object
#  8   Monthly_Charges        529 non-null    float64
#  9   Total_Charges          533 non-null    float64
#  10  Contract_Type          538 non-null    object
#  11  Payment_Method         526 non-null    object
#  12  Internet_Service       535 non-null    object
#  13  Tech_Support           530 non-null    object
# ...

# %%
df.describe()
# Out:
#               Age  Tenure_Months  Monthly_Charges  Total_Charges
# count  536.000000     534.000000       529.000000     533.000000
# mean    44.399254      36.406367      1335.269206   49745.287336
# std     18.556837      20.669599       715.972838   41644.111657
# min      3.000000       1.000000     -2454.770000  -99781.820000
# 25%     30.000000      19.000000       756.570000   18770.290000
# 50%     44.000000      38.000000      1306.800000   40649.600000
# 75%     57.000000      54.000000      1900.650000   75647.400000
# max    165.000000      72.000000      2492.510000  171429.830000

# %%
df.isnull().sum()
# Out:
# Customer_ID               0
# Customer_Name             9
# Gender                    6
# Age                       6
# State                    11
# City                      3
# Tenure_Months             8
# Subscription_Type        12
# Monthly_Charges          13
# Total_Charges             9
# Contract_Type             4
# Payment_Method           16
# Internet_Service          7
# Tech_Support             12
# Senior_Citizen            8
# Dependents                3
# Churn                     4
# Last_Interaction_Date     3
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(7)

# %%
df["Gender"].unique()
# Out:
# array(['Female', 'Male', ' male ', nan], dtype=object)

# %%
df["Contract_Type"].unique()
# Out:
# array(['One Year', 'Two Year', 'Month-to-Month', nan, 'Month-to-Month ',
#        'One Year '], dtype=object)

# %%
df["Subscription_Type"].unique()
# Out:
# array(['basic', 'Premium', 'Basic', 'Standard', nan, 'BASIC', 'Premium ',
#        'Basic ', 'Standard ', 'Premium  ', '  Basic'], dtype=object)

# %%
df["Payment_Method"].unique()
# Out:
# array(['UPI', 'Cash', 'Debit Card', nan, 'Credit Card', 'Net Banking',
#        'Credit Card  '], dtype=object)

# %%
df["Internet_Service"].unique()
# Out:
# array(['Fiber', 'DSL', '5G', 'Cable', nan, 'DSL  '], dtype=object)

# %%
df["Tech_Support"].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
df["Senior_Citizen"].unique()
# Out:
# array(['No', 'Yes', 'No ', nan], dtype=object)

# %%
df["Dependents"].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
df["Churn"].unique()
# Out:
# array(['No', 'Yes', 'YES', 'yes', nan], dtype=object)

# %%
df[["Age", "Tenure_Months", "Monthly_Charges", "Total_Charges"]].describe()
# Out:
#               Age  Tenure_Months  Monthly_Charges  Total_Charges
# count  536.000000     534.000000       529.000000     533.000000
# mean    44.399254      36.406367      1335.269206   49745.287336
# std     18.556837      20.669599       715.972838   41644.111657
# min      3.000000       1.000000     -2454.770000  -99781.820000
# 25%     30.000000      19.000000       756.570000   18770.290000
# 50%     44.000000      38.000000      1306.800000   40649.600000
# 75%     57.000000      54.000000      1900.650000   75647.400000
# max    165.000000      72.000000      2492.510000  171429.830000

# %%
df[(df["Age"] < 18) | (df["Age"] > 100)]
# Out:
#     Customer_ID Customer_Name  Gender    Age        State       City  \
# 5         C1005    Sneha Jain  Female  115.0      Gujarat      Surat
# 13        C1013    Neha Verma    Male    3.0      Gujarat      Surat
# 16        C1016   Priya Gupta  Female  120.0    Karnataka     Mysuru
# 22        C1022   Pooja Singh    Male    4.0      Gujarat  Ahmedabad
# 27        C1027   Rahul Singh    Male    5.0           UP     Kanpur
# 46        C1046    Sneha Jain  Female  140.0  Maharashtra       Pune
# 75        C1075   Priya Gupta  Female  137.0  Maharashtra    Mumbai
# 122       C1122    Sneha Jain  Female  121.0      Gujarat  Ahmedabad
# 202       C1202    Sneha Jain  Female  165.0           UP     Kanpur
# 537       C5005    Sneha Jain  Female  115.0      Gujarat      Surat
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 5              1.0               NaN          1633.64        1707.64
# ...

# %%
df[(df["Monthly_Charges"] < 0)]
# Out:
#     Customer_ID Customer_Name  Gender   Age        State       City  \
# 97        C1097   Rohit Kumar  Female  65.0           UP    Lucknow
# 123       C1123   Amit Sharma  Female  28.0      Gujarat  Ahmedabad
# 126       C1126   Rahul Singh    Male  22.0        Delhi      Delhi
# 166       C1166   Rahul Singh  Female  22.0  Maharashtra     Mumbai
# 217       C1217   Rohit Kumar  Female  20.0           UP    Lucknow
# 457       C1457  Anjali Mehta  Female  42.0           UP     Kanpur
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 97            60.0             Basic         -1042.36       62577.60
# 123           57.0             Basic         -1621.45       92655.65
# 126           28.0          Standard          -680.31      -18976.68
# 166           40.0             Basic         -1838.55       73086.00
# 217           66.0          Standard         -2454.77      162302.82
# 457           29.0             Basic          -904.51      -25767.79
#
# ...

# %%
df[(df["Total_Charges"] < 0)]
# Out:
#     Customer_ID     Customer_Name  Gender   Age        State       City  \
# 17        C1017  Abhishek Jaiswal  Female   NaN      Gujarat  Ahmedabad
# 36        C1036       Rohit Kumar    Male  48.0           UP     Kanpur
# 94        C1094       Amit Sharma    Male  63.0  Maharashtra     Mumbai
# 126       C1126       Rahul Singh    Male  22.0        Delhi      Delhi
# 457       C1457      Anjali Mehta  Female  42.0           UP     Kanpur
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 17            48.0             Basic          1975.23      -94534.04
# 36            70.0           Premium          1285.52      -89554.40
# 94            43.0           Premium          2331.74      -99781.82
# 126           28.0          Standard          -680.31      -18976.68
# 457           29.0             Basic          -904.51      -25767.79
#
#       Contract_Type Payment_Method Internet_Service Tech_Support  \
# ...

# %%
df["Last_Interaction_Date"] .head(10)
# Out:
# 0    12-10-2025
# 1    05-03-2026
# 2    20-02-2026
# 3    07-06-2026
# 4    02-04-2026
# 5    13-03-2026
# 6    26-12-2025
# 7    14-01-2025
# 8    28-02-2025
# 9    29-11-2025
# Name: Last_Interaction_Date, dtype: object

# %%
df["Last_Interaction_Date"].unique()
# Out:
# array(['12-10-2025', '05-03-2026', '20-02-2026', '07-06-2026',
#        '02-04-2026', '13-03-2026', '26-12-2025', '14-01-2025',
#        '28-02-2025', '29-11-2025', '03-10-2025', '32/13/2025',
#        '27-09-2025', '09-04-2025', '05-10-2025', '01-01-2026',
#        '12-01-2026', '13-08-2025', '04-06-2025', '05-07-2025',
#        '27-03-2025', '26-03-2026', '27-06-2026', '22-01-2026',
#        '06-03-2026', '29-04-2026', '12-06-2026', '17-08-2025',
#        '02-08-2025', '16-01-2025', '26-06-2026', '25-04-2026',
#        '04-01-2026', '18-04-2026', '07-12-2025', '04-04-2025',
#        '21-09-2025', '17-07-2025', '16-10-2025', '29-01-2026',
#        '01-06-2026', '06-10-2025', '16-11-2025', '01-09-2025',
#        '21-01-2025', '25-01-2026', '17-05-2026', '21-01-2026',
#        '31-01-2025', '03-03-2026', '18-01-2025', '06-06-2026',
#        '24-03-2026', '11-06-2025', '27-04-2026', '13-04-2026',
#        '28-02-2026', '07-02-2026', '13-06-2026', '12-02-2025',
# ...

# %%
df[df["Customer_ID"].duplicated(keep=False)].sort_values("Customer_ID")
# Out:
#     Customer_ID  Customer_Name  Gender   Age        State       City  \
# 18        C1018    Amit Sharma     NaN  41.0      Gujarat  Ahmedabad
# 524       C1018  Anikta Sharma  Female  41.0      Gujarat  Ahmedabad
# 531       C1018  Anikta Sharma  Female  41.0      Gujarat  Ahmedabad
# 518       C1518    Vikas Yadav    Male  47.0  Maharashtra       Pune
# 525       C1518    Vikas Yadav    Male  47.0  Maharashtra       Pune
# 519       C1519            NaN    Male  52.0    Karnataka  Bengaluru
# 526       C1519            NaN    Male  52.0    Karnataka  Bengaluru
# 520       C1520    Pooja Singh    Male  69.0           UP    Lucknow
# 527       C1520    Pooja Singh    Male  69.0           UP    Lucknow
# 521       C1521    Mohit Arora     NaN  54.0          NaN  Bengaluru
# 528       C1521    Mohit Arora     NaN  54.0          NaN  Bengaluru
# 522       C1522    Mohit Arora  Female  49.0           UP     Kanpur
# 529       C1522    Mohit Arora  Female  49.0           UP     Kanpur
# ...

# %%
df["Customer_ID"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.groupby("Gender")["Age"].median()
# Out:
# Gender
#  male     26.0
# Female    42.0
# Male      45.5
# Name: Age, dtype: float64

# %%
df.head()
# Out:
#   Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0       C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 1       C1001       Rohit Kumar    Male   NaN        Delhi      Noida
# 2       C1002       Pooja Singh  Female  42.0           UP     Kanpur
# 3       C1003               NaN    Male  59.0    Karnataka  Bengaluru
# 4       C1004       Mohit Arora   male   26.0      Gujarat  Ahmedabad
#
#    Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 0           58.0             basic          1614.26       93273.08
# 1           36.0           Premium           429.60       15858.60
# 2           13.0             Basic           555.03        6869.39
# 3           55.0          Standard              NaN      101349.10
# 4            6.0           Premium           314.02        1926.12
#
#     Contract_Type Payment_Method Internet_Service Tech_Support Senior_Citizen  \
# ...

# %%
df_clean = df.copy()

# %%
# Removing WhiteSpaces

# %%
df_clean["Gender"] = df_clean["Gender"].str.strip()

# %%
df_clean["State"] = df_clean["State"].str.strip()

# %%
df_clean["Contract_Type"] = df_clean["Contract_Type"].str.strip()

# %%
df_clean["Subscription_Type"] = df_clean["Subscription_Type"].str.strip()

# %%
df_clean["Payment_Method"] = df_clean["Payment_Method"].str.strip()

# %%
df_clean["Internet_Service"] = df_clean["Internet_Service"].str.strip()

# %%
df_clean["Tech_Support"] = df_clean["Tech_Support"].str.strip()

# %%
df_clean["Senior_Citizen"] = df_clean["Senior_Citizen"].str.strip()

# %%
df_clean["Dependents"] = df_clean["Dependents"].str.strip()

# %%
df_clean["Churn"] = df_clean["Churn"].str.strip()

# %%
# Removing Inconsistent values / Standard capitization

# %%
df_clean["Gender"] = df_clean["Gender"].replace({
    "male" : "Male",
    "FeMale" : "Female"
})

# %%
df_clean["Subscription_Type"] = df_clean["Subscription_Type"].replace({
    "basic" : "Basic",
    "BASIC" : "Basic"
})

# %%
df_clean["Churn"] = df_clean["Churn"].replace({
    "YES" : "Yes",
    "yes" : "Yes"
})

# %%
df_clean["Dependents"].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
# Missing Values

# %%
df_clean["Customer_Name"] = df_clean["Customer_Name"].fillna("Unknown")

# %%
df_clean["Customer_Name"].isna().sum()
# Out:
# np.int64(0)

# %%
df_clean[df_clean["State"].isna()][["Customer_ID", "City", "State"]]
# Out:
#     Customer_ID       City State
# 25        C1025      Delhi   NaN
# 108       C1108  Ahmedabad   NaN
# 113       C1113       Pune   NaN
# 148       C1148  Bengaluru   NaN
# 160       C1160      Noida   NaN
# 177       C1177  Ahmedabad   NaN
# 420       C1420      Surat   NaN
# 473       C1473      Surat   NaN
# 509       C1509      Surat   NaN
# 521       C1521  Bengaluru   NaN
# 528       C1521  Bengaluru   NaN

# %%
city_state_mapping = df_clean.groupby("City")["State"].first()

# %%
df_clean["State"] = df_clean["State"].fillna(df_clean["City"].map(city_state_mapping))

# %%
df_clean["State"].isna().sum()
# Out:
# np.int64(0)

# %%
# Cheaking for the city-state mapping

# %%
df_clean[df_clean["City"].isna()][
    ["Customer_ID", "State", "City"]
]
# Out:
#     Customer_ID  State City
# 31        C1031     UP  NaN
# 147       C1147  Delhi  NaN
# 437       C1437     UP  NaN

# %%
df_clean[df_clean["City"].isna()][
    ["Customer_ID", "Customer_Name", "Gender", "Age",
     "State", "Tenure_Months", "Subscription_Type",
     "Monthly_Charges", "Total_Charges",
     "Contract_Type", "Payment_Method",
     "Internet_Service", "Churn"]
]
# Out:
#     Customer_ID        Customer_Name  Gender   Age  State  Tenure_Months  \
# 31        C1031  Abhishek Jaiswal       Male  37.0     UP           23.0
# 147       C1147          Vikas Yadav     NaN  62.0  Delhi           42.0
# 437       C1437           Sneha Jain  Female  56.0     UP            2.0
#
#     Subscription_Type  Monthly_Charges  Total_Charges   Contract_Type  \
# 31            Premium          1555.38       35431.74        One Year
# 147             Basic          2492.51      104747.42  Month-to-Month
# 437           Premium           873.54        1712.08  Month-to-Month
#
#     Payment_Method Internet_Service Churn
# 31      Debit Card            Fiber   Yes
# 147    Net Banking            Fiber    No
# 437            NaN               5G    No

# %%
df_clean["City"] = df_clean["City"].fillna("Unknown")

# %%
# Cheaking Age columns

# %%
df_clean.loc[df_clean["Age"] < 18, "Age"] = np.nan

# %%
df_clean.loc[df_clean["Age"] > 100, "Age"] = np.nan

# %%
df_clean["Age"].describe()
# Out:
# count    526.000000
# mean      43.484791
# std       15.435357
# min       18.000000
# 25%       30.000000
# 50%       43.500000
# 75%       56.000000
# max       70.000000
# Name: Age, dtype: float64

# %%
df_clean["Age"].isna().sum()
# Out:
# np.int64(16)

# %%
df_clean["Age"].median()
# Out:
# np.float64(43.5)

# %%
df_clean.groupby("Gender")["Age"].median()
# Out:
# Gender
# Female    42.0
# Male      46.0
# Name: Age, dtype: float64

# %%
df_clean[df_clean["Age"].isna()][
    ["Customer_ID", "Gender", "Age"]
]
# Out:
#     Customer_ID  Gender  Age
# 1         C1001    Male  NaN
# 5         C1005  Female  NaN
# 11        C1011    Male  NaN
# 13        C1013    Male  NaN
# 16        C1016  Female  NaN
# 17        C1017  Female  NaN
# 22        C1022    Male  NaN
# 27        C1027    Male  NaN
# 46        C1046  Female  NaN
# 75        C1075  Female  NaN
# 78        C1078  Female  NaN
# 122       C1122  Female  NaN
# 202       C1202  Female  NaN
# 306       C1306    Male  NaN
# 533       C5001    Male  NaN
# 537       C5005  Female  NaN

# %%
gender_age_median = df_clean.groupby("Gender")["Age"].transform("median")

# %%
gender_age_median.head(20)
# Out:
# 0     42.0
# 1     46.0
# 2     42.0
# 3     46.0
# 4     46.0
# 5     42.0
# 6     42.0
# 7     46.0
# 8     46.0
# 9     46.0
# 10    46.0
# 11    46.0
# 12    42.0
# 13    46.0
# 14    46.0
# 15    46.0
# 16    42.0
# 17    42.0
# 18     NaN
# 19    46.0
# Name: Age, dtype: float64

# %%
df_clean["Age"] = df_clean["Age"].fillna(gender_age_median)

# %%
df_clean["Age"].isnull().sum()
# Out:
# np.int64(0)

# %%
df_clean["Age"]
# Out:
# 0      35.0
# 1      46.0
# 2      42.0
# 3      59.0
# 4      26.0
#        ...
# 537    42.0
# 538    18.0
# 539    61.0
# 540    45.0
# 541    25.0
# Name: Age, Length: 542, dtype: float64

# %%
# Tenure Month

# %%
df_clean["Tenure_Months"].describe()
# Out:
# count    534.000000
# mean      36.406367
# std       20.669599
# min        1.000000
# 25%       19.000000
# 50%       38.000000
# 75%       54.000000
# max       72.000000
# Name: Tenure_Months, dtype: float64

# %%
df_clean[df_clean["Tenure_Months"] <= 0][["Customer_ID", "Tenure_Months"]]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Tenure_Months]
# Index: []

# %%
df_clean.groupby("Contract_Type")["Tenure_Months"].median()
# Out:
# Contract_Type
# Month-to-Month    42.0
# One Year          38.0
# Two Year          32.0
# Name: Tenure_Months, dtype: float64

# %%
df_clean[df_clean["Tenure_Months"].isna()][
    ["Customer_ID", "Contract_Type", "Subscription_Type", "Churn"]
]
# Out:
#     Customer_ID   Contract_Type Subscription_Type Churn
# 145       C1145  Month-to-Month           Premium   Yes
# 178       C1178  Month-to-Month           Premium    No
# 257       C1257        Two Year          Standard    No
# 274       C1274        One Year             Basic   Yes
# 331       C1331  Month-to-Month          Standard   Yes
# 400       C1400        Two Year             Basic    No
# 520       C1520  Month-to-Month           Premium    No
# 527       C1520  Month-to-Month           Premium    No

# %%
contract_tenure_median = df_clean.groupby("Contract_Type")["Tenure_Months"].transform("median")

# %%
contract_tenure_median
# Out:
# 0      38.0
# 1      32.0
# 2      42.0
# 3      32.0
# 4      38.0
#        ...
# 537    32.0
# 538    42.0
# 539    38.0
# 540    32.0
# 541    42.0
# Name: Tenure_Months, Length: 542, dtype: float64

# %%
df_clean["Tenure_Months"] = df_clean["Tenure_Months"].fillna(contract_tenure_median)

# %%
df_clean["Tenure_Months"].isna().sum()
# Out:
# np.int64(0)

# %%
# Monthly Charges - dealing with negative values

# %%
df_clean[df_clean["Monthly_Charges"] < 0][
    ["Customer_ID", "Age", "Tenure_Months", "Subscription_Type",
     "Monthly_Charges", "Total_Charges", "Contract_Type", "Churn"]
]
# Out:
#     Customer_ID   Age  Tenure_Months Subscription_Type  Monthly_Charges  \
# 97        C1097  65.0           60.0             Basic         -1042.36
# 123       C1123  28.0           57.0             Basic         -1621.45
# 126       C1126  22.0           28.0          Standard          -680.31
# 166       C1166  22.0           40.0             Basic         -1838.55
# 217       C1217  20.0           66.0          Standard         -2454.77
# 457       C1457  42.0           29.0             Basic          -904.51
#
#      Total_Charges   Contract_Type Churn
# 97        62577.60        One Year    No
# 123       92655.65  Month-to-Month   Yes
# 126      -18976.68        One Year   Yes
# 166       73086.00        One Year    No
# 217      162302.82        One Year   Yes
# 457      -25767.79  Month-to-Month    No

# %%
df_clean["Monthly_Charges"].describe()
# Out:
# count     529.000000
# mean     1335.269206
# std       715.972838
# min     -2454.770000
# 25%       756.570000
# 50%      1306.800000
# 75%      1900.650000
# max      2492.510000
# Name: Monthly_Charges, dtype: float64

# %%
df_clean["Monthly_Charges"] = df_clean["Monthly_Charges"].abs()

# %%
df_clean[df_clean["Monthly_Charges"] < 0][
    ["Customer_ID", "Monthly_Charges"]
]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Monthly_Charges]
# Index: []

# %%
df_clean["Monthly_Charges"].describe()
# Out:
# count     529.000000
# mean     1367.563913
# std       652.046459
# min       302.540000
# 25%       764.880000
# 50%      1341.520000
# 75%      1908.060000
# max      2492.510000
# Name: Monthly_Charges, dtype: float64

# %%
# dealing with empty values

# %%
df_clean.groupby("Subscription_Type")["Monthly_Charges"].median()
# Out:
# Subscription_Type
# Basic       1294.530
# Premium     1357.755
# Standard    1285.780
# Name: Monthly_Charges, dtype: float64

# %%
df_clean[df_clean["Monthly_Charges"].isna()][
    ["Customer_ID", "Subscription_Type", "Contract_Type",
     "Internet_Service", "Tenure_Months", "Total_Charges"]
]
# Out:
#     Customer_ID Subscription_Type   Contract_Type Internet_Service  \
# 3         C1003          Standard        Two Year               5G
# 46        C1046             Basic        Two Year              DSL
# 81        C1081          Standard  Month-to-Month            Fiber
# 117       C1117           Premium  Month-to-Month               5G
# 142       C1142           Premium  Month-to-Month              DSL
# 173       C1173             Basic        One Year               5G
# 178       C1178           Premium  Month-to-Month            Fiber
# 221       C1221             Basic        Two Year            Cable
# 263       C1263             Basic        Two Year            Cable
# 420       C1420             Basic        One Year              DSL
# 521       C1521               NaN             NaN            Fiber
# 528       C1521               NaN             NaN            Fiber
# 535       C5003          Standard        Two Year               5G
#
# ...

# %%
subscription_monthly_median = df_clean.groupby(
    "Subscription_Type"
)["Monthly_Charges"].transform("median")

# %%
df_clean["Monthly_Charges"] = df_clean["Monthly_Charges"].fillna(
    subscription_monthly_median
)

# %%
# dealing with these two values with nan

# %%
df_clean[df_clean["Monthly_Charges"].isna()][
    ["Customer_ID", "Subscription_Type", "Monthly_Charges"]
]
# Out:
#     Customer_ID Subscription_Type  Monthly_Charges
# 521       C1521               NaN              NaN
# 528       C1521               NaN              NaN

# %%
(df_clean["Total_Charges"] / df_clean["Tenure_Months"]).describe()
# Out:
# count     533.000000
# mean     1345.956964
# std       712.428330
# min     -2320.507442
# 25%       755.315455
# 50%      1321.160000
# 75%      1924.886087
# max      3361.977895
# dtype: float64

# %%
df_clean[df_clean["Customer_ID"] == "C1521"][
    ["Customer_ID", "Tenure_Months", "Monthly_Charges", "Total_Charges"]
]
# Out:
#     Customer_ID  Tenure_Months  Monthly_Charges  Total_Charges
# 521       C1521            1.0              NaN        1705.68
# 528       C1521            1.0              NaN        1705.68

# %%
df_clean[
    (df_clean["Internet_Service"] == "Fiber") &
    (df_clean["Tenure_Months"] == 1)
][
    ["Customer_ID", "Subscription_Type", "Tenure_Months",
     "Monthly_Charges", "Total_Charges"]
]
# Out:
#     Customer_ID Subscription_Type  Tenure_Months  Monthly_Charges  \
# 218       C1218             Basic            1.0          1666.22
# 393       C1393             Basic            1.0          2093.42
# 436       C1436          Standard            1.0           379.70
# 521       C1521               NaN            1.0              NaN
# 528       C1521               NaN            1.0              NaN
#
#      Total_Charges
# 218        1714.22
# 393        1966.42
# 436         772.70
# 521        1705.68
# 528        1705.68

# %%
df_clean[
    (df_clean["Internet_Service"] == "Fiber") &
    (df_clean["Tenure_Months"] == 1)
]["Monthly_Charges"].median()
# Out:
# np.float64(1666.22)

# %%
fiber_1month_median = df_clean[
    (df_clean["Internet_Service"] == "Fiber") &
    (df_clean["Tenure_Months"] == 1)
]["Monthly_Charges"].median()

# %%
df_clean["Monthly_Charges"] = df_clean["Monthly_Charges"].fillna(
    fiber_1month_median
)

# %%
df_clean["Monthly_Charges"].isna().sum()
# Out:
# np.int64(0)

# %%
# Total charges

# %%
df_clean[df_clean["Total_Charges"] < 0][
    ["Customer_ID", "Tenure_Months",
     "Monthly_Charges", "Total_Charges",
     "Subscription_Type", "Contract_Type"]
]
# Out:
#     Customer_ID  Tenure_Months  Monthly_Charges  Total_Charges  \
# 17        C1017           48.0          1975.23      -94534.04
# 36        C1036           70.0          1285.52      -89554.40
# 94        C1094           43.0          2331.74      -99781.82
# 126       C1126           28.0           680.31      -18976.68
# 457       C1457           29.0           904.51      -25767.79
#
#     Subscription_Type   Contract_Type
# 17              Basic  Month-to-Month
# 36            Premium  Month-to-Month
# 94            Premium        One Year
# 126          Standard        One Year
# 457             Basic  Month-to-Month

# %%
df_clean["Total_Charges"] = df_clean["Total_Charges"].abs()

# %%
df_clean[df_clean["Total_Charges"] < 0][
    ["Customer_ID", "Total_Charges"]
]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Total_Charges]
# Index: []

# %%
df_clean["Total_Charges"].describe()
# Out:
# count       533.000000
# mean      50978.363246
# std       40122.296422
# min         354.120000
# 25%       19169.900000
# 50%       40952.260000
# 75%       75799.150000
# max      171429.830000
# Name: Total_Charges, dtype: float64

# %%
df_clean[df_clean["Total_Charges"].isna()][
    ["Customer_ID", "Tenure_Months", "Monthly_Charges",
     "Total_Charges", "Subscription_Type",
     "Contract_Type", "Churn"]
]
# Out:
#     Customer_ID  Tenure_Months  Monthly_Charges  Total_Charges  \
# 9         C1009           30.0          1341.52            NaN
# 12        C1012           18.0          1722.85            NaN
# 160       C1160           64.0          2306.42            NaN
# 249       C1249           63.0          1098.58            NaN
# 308       C1308           28.0          2195.67            NaN
# 368       C1368           22.0          1777.10            NaN
# 520       C1520           42.0           687.44            NaN
# 527       C1520           42.0           687.44            NaN
# 541       C5009           30.0          1341.52            NaN
#
#     Subscription_Type   Contract_Type Churn
# 9               Basic  Month-to-Month    No
# 12              Basic        One Year   Yes
# 160               NaN        Two Year   Yes
# 249             Basic  Month-to-Month   Yes
# 308          Standard        One Year    No
# 368               NaN        One Year    No
# ...

# %%
calculated_total = df_clean["Monthly_Charges"] * df_clean["Tenure_Months"]

# %%
df_clean[df_clean["Total_Charges"].isna()][
    ["Customer_ID", "Monthly_Charges", "Tenure_Months", "Total_Charges"]
].assign(Calculated_Total=calculated_total)
# Out:
#     Customer_ID  Monthly_Charges  Tenure_Months  Total_Charges  \
# 9         C1009          1341.52           30.0            NaN
# 12        C1012          1722.85           18.0            NaN
# 160       C1160          2306.42           64.0            NaN
# 249       C1249          1098.58           63.0            NaN
# 308       C1308          2195.67           28.0            NaN
# 368       C1368          1777.10           22.0            NaN
# 520       C1520           687.44           42.0            NaN
# 527       C1520           687.44           42.0            NaN
# 541       C5009          1341.52           30.0            NaN
#
#      Calculated_Total
# 9            40245.60
# 12           31011.30
# 160         147610.88
# 249          69210.54
# 308          61478.76
# 368          39096.20
# 520          28872.48
# 527          28872.48
# 541          40245.60

# %%
df_clean["Total_Charges"] = df_clean["Total_Charges"].fillna(calculated_total)

# %%
df_clean["Total_Charges"].isna().sum()
# Out:
# np.int64(0)

# %%
# Tech_Support

# %%
df_clean["Tech_Support"].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
df_clean["Tech_Support"].isna().sum()
# Out:
# np.int64(12)

# %%
df_clean[df_clean["Tech_Support"].isna()][
    ["Customer_ID", "Internet_Service", "Subscription_Type",
     "Contract_Type", "Tech_Support", "Churn"]
]
# Out:
#     Customer_ID Internet_Service Subscription_Type   Contract_Type  \
# 17        C1017            Fiber             Basic  Month-to-Month
# 20        C1020               5G           Premium  Month-to-Month
# 38        C1038            Cable          Standard        Two Year
# 109       C1109              DSL             Basic        Two Year
# 126       C1126            Cable          Standard        One Year
# 180       C1180            Cable           Premium        One Year
# 237       C1237            Cable           Premium  Month-to-Month
# 310       C1310            Fiber           Premium  Month-to-Month
# 507       C1507            Fiber           Premium        Two Year
# 514       C1514            Cable           Premium        One Year
# 522       C1522              DSL           Premium  Month-to-Month
# 529       C1522              DSL           Premium  Month-to-Month
#
#     Tech_Support Churn
# 17           NaN    No
# 20           NaN    No
# ...

# %%
df_clean.groupby("Internet_Service")["Tech_Support"].value_counts()
# Out:
# Internet_Service  Tech_Support
# 5G                No              80
#                   Yes             45
# Cable             Yes             71
#                   No              57
# DSL               Yes             69
#                   No              59
# Fiber             Yes             72
#                   No              70
# Name: count, dtype: int64

# %%
df_clean.groupby("Subscription_Type")["Tech_Support"].value_counts()
# Out:
# Subscription_Type  Tech_Support
# Basic              Yes             91
#                    No              78
# Premium            Yes             91
#                    No              90
# Standard           No              98
#                    Yes             70
# Name: count, dtype: int64

# %%
df_clean.groupby("Subscription_Type")["Tech_Support"].value_counts()
# Out:
# Subscription_Type  Tech_Support
# Basic              Yes             91
#                    No              78
# Premium            Yes             91
#                    No              90
# Standard           No              98
#                    Yes             70
# Name: count, dtype: int64

# %%
df_clean.groupby("Subscription_Type")["Tech_Support"].agg(lambda x: x.mode()[0])
# Out:
# Subscription_Type
# Basic       Yes
# Premium     Yes
# Standard     No
# Name: Tech_Support, dtype: object

# %%
tech_support_mode = df_clean.groupby("Subscription_Type")["Tech_Support"].agg(
    lambda x: x.mode()[0]
)

# %%
df_clean["Tech_Support"] = df_clean["Tech_Support"].fillna(
    df_clean["Subscription_Type"].map(tech_support_mode)
)

# %%
df_clean["Tech_Support"].isna().sum()
# Out:
# np.int64(0)

# %%
# Dependents

# %%
df_clean["Dependents"].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
df_clean["Dependents"].isna().sum()
# Out:
# np.int64(3)

# %%
df_clean[df_clean["Dependents"].isna()][
    ["Customer_ID", "Age", "Subscription_Type",
     "Contract_Type", "Dependents", "Churn"]
]
# Out:
#     Customer_ID   Age Subscription_Type Contract_Type Dependents Churn
# 12        C1012  35.0             Basic      One Year        NaN   Yes
# 518       C1518  47.0           Premium      One Year        NaN   Yes
# 525       C1518  47.0           Premium      One Year        NaN   Yes

# %%
# last interaction date

# %%
df_clean["Last_Interaction_Date"].isna().sum()
# Out:
# np.int64(3)

# %%
df_clean["Last_Interaction_Date"].unique()
# Out:
# array(['12-10-2025', '05-03-2026', '20-02-2026', '07-06-2026',
#        '02-04-2026', '13-03-2026', '26-12-2025', '14-01-2025',
#        '28-02-2025', '29-11-2025', '03-10-2025', '32/13/2025',
#        '27-09-2025', '09-04-2025', '05-10-2025', '01-01-2026',
#        '12-01-2026', '13-08-2025', '04-06-2025', '05-07-2025',
#        '27-03-2025', '26-03-2026', '27-06-2026', '22-01-2026',
#        '06-03-2026', '29-04-2026', '12-06-2026', '17-08-2025',
#        '02-08-2025', '16-01-2025', '26-06-2026', '25-04-2026',
#        '04-01-2026', '18-04-2026', '07-12-2025', '04-04-2025',
#        '21-09-2025', '17-07-2025', '16-10-2025', '29-01-2026',
#        '01-06-2026', '06-10-2025', '16-11-2025', '01-09-2025',
#        '21-01-2025', '25-01-2026', '17-05-2026', '21-01-2026',
#        '31-01-2025', '03-03-2026', '18-01-2025', '06-06-2026',
#        '24-03-2026', '11-06-2025', '27-04-2026', '13-04-2026',
#        '28-02-2026', '07-02-2026', '13-06-2026', '12-02-2025',
# ...

# %%
date_check = pd.to_datetime(
    df_clean["Last_Interaction_Date"],
    format="%d-%m-%Y",
    errors="coerce"
)

# %%
date_check.isna().sum()
# Out:
# np.int64(4)

# %%
df_clean[date_check.isna()][
    ["Customer_ID", "Last_Interaction_Date"]
]
# Out:
#     Customer_ID Last_Interaction_Date
# 11        C1011            32/13/2025
# 382       C1382                   NaN
# 518       C1518                   NaN
# 525       C1518                   NaN

# %%
df_clean["Last_Interaction_Date"] = date_check

# %%
df_clean["Last_Interaction_Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_clean["Last_Interaction_Date"].isna().sum()
# Out:
# np.int64(4)

# %%
# resolving duplicates values

# %%
df_clean[df_clean["Customer_ID"].duplicated(keep=False)].sort_values("Customer_ID")
# Out:
#     Customer_ID  Customer_Name  Gender   Age        State       City  \
# 18        C1018    Amit Sharma     NaN  41.0      Gujarat  Ahmedabad
# 524       C1018  Anikta Sharma  Female  41.0      Gujarat  Ahmedabad
# 531       C1018  Anikta Sharma  Female  41.0      Gujarat  Ahmedabad
# 518       C1518    Vikas Yadav    Male  47.0  Maharashtra       Pune
# 525       C1518    Vikas Yadav    Male  47.0  Maharashtra       Pune
# 519       C1519        Unknown    Male  52.0    Karnataka  Bengaluru
# 526       C1519        Unknown    Male  52.0    Karnataka  Bengaluru
# 520       C1520    Pooja Singh    Male  69.0           UP    Lucknow
# 527       C1520    Pooja Singh    Male  69.0           UP    Lucknow
# 521       C1521    Mohit Arora     NaN  54.0    Karnataka  Bengaluru
# 528       C1521    Mohit Arora     NaN  54.0    Karnataka  Bengaluru
# 522       C1522    Mohit Arora  Female  49.0           UP     Kanpur
# 529       C1522    Mohit Arora  Female  49.0           UP     Kanpur
# ...

# %%
df_clean["Customer_ID"].duplicated().sum()
# Out:
# np.int64(8)

# %%
df_clean["Customer_ID"].nunique()
# Out:
# 534

# %%
df_clean[df_clean["Customer_ID"].duplicated(keep=False)] \
    .sort_values("Customer_ID")
# Out:
#     Customer_ID  Customer_Name  Gender   Age        State       City  \
# 18        C1018    Amit Sharma     NaN  41.0      Gujarat  Ahmedabad
# 524       C1018  Anikta Sharma  Female  41.0      Gujarat  Ahmedabad
# 531       C1018  Anikta Sharma  Female  41.0      Gujarat  Ahmedabad
# 518       C1518    Vikas Yadav    Male  47.0  Maharashtra       Pune
# 525       C1518    Vikas Yadav    Male  47.0  Maharashtra       Pune
# 519       C1519        Unknown    Male  52.0    Karnataka  Bengaluru
# 526       C1519        Unknown    Male  52.0    Karnataka  Bengaluru
# 520       C1520    Pooja Singh    Male  69.0           UP    Lucknow
# 527       C1520    Pooja Singh    Male  69.0           UP    Lucknow
# 521       C1521    Mohit Arora     NaN  54.0    Karnataka  Bengaluru
# 528       C1521    Mohit Arora     NaN  54.0    Karnataka  Bengaluru
# 522       C1522    Mohit Arora  Female  49.0           UP     Kanpur
# 529       C1522    Mohit Arora  Female  49.0           UP     Kanpur
# ...

# %%
df_clean.duplicated().sum()
# Out:
# np.int64(7)

# %%
df_clean = df_clean.drop_duplicates()

# %%
df_clean.shape
# Out:
# (535, 18)

# %%
df_clean["Customer_ID"].duplicated().sum()
# Out:
# np.int64(1)

# %%
df_clean[df_clean["Customer_ID"] == "C1018"]
# Out:
#     Customer_ID  Customer_Name  Gender   Age    State       City  \
# 18        C1018    Amit Sharma     NaN  41.0  Gujarat  Ahmedabad
# 524       C1018  Anikta Sharma  Female  41.0  Gujarat  Ahmedabad
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# 18            48.0           Premium          2328.32      111299.36
# 524           48.0           Premium          2328.32      111299.36
#
#       Contract_Type Payment_Method Internet_Service Tech_Support  \
# 18   Month-to-Month    Net Banking            Fiber          Yes
# 524  Month-to-Month    Net Banking            Fiber          Yes
#
#     Senior_Citizen Dependents Churn Last_Interaction_Date
# 18              No        Yes    No            2025-06-04
# 524             No        Yes    No            2025-06-04

# %%
df_clean = df_clean[
    ~(
        (df_clean["Customer_ID"] == "C1018") &
        (df_clean["Customer_Name"] == "Amit Sharma")
    )
]

# %%
df_clean["Customer_ID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_clean
# Out:
#     Customer_ID     Customer_Name  Gender   Age        State       City  \
# 0         C1000  Abhishek Jaiswal  Female  35.0  Maharashtra       Pune
# 1         C1001       Rohit Kumar    Male  46.0        Delhi      Noida
# 2         C1002       Pooja Singh  Female  42.0           UP     Kanpur
# 3         C1003           Unknown    Male  59.0    Karnataka  Bengaluru
# 4         C1004       Mohit Arora    Male  26.0      Gujarat  Ahmedabad
# ..          ...               ...     ...   ...          ...        ...
# 537       C5005        Sneha Jain  Female  42.0      Gujarat      Surat
# 538       C5006        Neha Verma  Female  18.0        Delhi      Noida
# 539       C5007       Vikas Yadav    Male  61.0        Delhi
# 540       C5008       Mohit Arora    Male  45.0      Gujarat  Ahmedabad
# 541       C5009       Rahul Singh    Male  25.0           UP     Kanpur
#
#      Tenure_Months Subscription_Type  Monthly_Charges  Total_Charges  \
# ...

# %%
# missing values

# %%
df_clean["Gender"].isna().sum()
# Out:
# np.int64(4)

# %%
df_clean[df_clean["Gender"].isna()][
    ["Customer_ID", "Customer_Name", "Age", "State", "City",
     "Subscription_Type", "Contract_Type", "Churn", "Gender"]
]
# Out:
#     Customer_ID Customer_Name   Age      State       City Subscription_Type  \
# 147       C1147   Vikas Yadav  62.0      Delhi    Unknown             Basic
# 232       C1232   Rahul Singh  46.0    Gujarat  Ahmedabad           Premium
# 456       C1456   Amit Sharma  47.0  Karnataka  Bengaluru           Premium
# 521       C1521   Mohit Arora  54.0  Karnataka  Bengaluru               NaN
#
#       Contract_Type Churn Gender
# 147  Month-to-Month    No    NaN
# 232        One Year    No    NaN
# 456        Two Year    No    NaN
# 521             NaN   NaN    NaN

# %%
df_clean["Gender"] = df_clean["Gender"].fillna("Unknown")

# %%
df_clean["Gender"].isna().sum()
# Out:
# np.int64(0)

# %%
df_clean["Gender"].value_counts()
# Out:
# Gender
# Female     270
# Male       260
# Unknown      4
# Name: count, dtype: int64

# %%
df_clean["Subscription_Type"].isna().sum()
# Out:
# np.int64(11)

# %%
df_clean[df_clean["Subscription_Type"].isna()][
    ["Customer_ID", "Age", "Gender", "Tenure_Months",
     "Monthly_Charges", "Total_Charges",
     "Contract_Type", "Internet_Service", "Churn"]
]
# Out:
#     Customer_ID   Age   Gender  Tenure_Months  Monthly_Charges  Total_Charges  \
# 5         C1005  42.0   Female            1.0          1633.64        1707.64
# 25        C1025  70.0     Male           42.0          1516.78       64151.76
# 56        C1056  41.0   Female           67.0          2193.44      146941.48
# 72        C1072  18.0     Male            2.0          1914.24        3962.48
# 143       C1143  24.0   Female           27.0           449.90       12606.30
# 160       C1160  67.0     Male           64.0          2306.42      147610.88
# 179       C1179  56.0   Female            1.0          1671.92        2065.92
# 238       C1238  60.0   Female           53.0          1022.84       53890.52
# 368       C1368  47.0     Male           22.0          1777.10       39096.20
# 521       C1521  54.0  Unknown            1.0          1666.22        1705.68
# 537       C5005  42.0   Female            1.0          1633.64        1707.64
#
# ...

# %%
df_clean["Subscription_Type"].value_counts()
# Out:
# Subscription_Type
# Premium     183
# Basic       171
# Standard    169
# Name: count, dtype: int64

# %%
subscription_mode = df_clean["Subscription_Type"].mode()[0]
subscription_mode
# Out:
# 'Premium'

# %%
df_clean["Subscription_Type"] = df_clean["Subscription_Type"].fillna(subscription_mode)

# %%
df_clean["Subscription_Type"].isna().sum()
# Out:
# np.int64(0)

# %%
df_clean["Subscription_Type"].value_counts()
# Out:
# Subscription_Type
# Premium     194
# Basic       171
# Standard    169
# Name: count, dtype: int64

# %%
df_clean["Contract_Type"].isna().sum()
# Out:
# np.int64(3)

# %%
df_clean[df_clean["Contract_Type"].isna()][
    ["Customer_ID", "Subscription_Type", "Tenure_Months",
     "Monthly_Charges", "Total_Charges",
     "Internet_Service", "Churn"]
]
# Out:
#     Customer_ID Subscription_Type  Tenure_Months  Monthly_Charges  \
# 57        C1057           Premium           72.0          1766.91
# 252       C1252             Basic           58.0          1633.30
# 521       C1521           Premium            1.0          1666.22
#
#      Total_Charges Internet_Service Churn
# 57       126942.52               5G    No
# 252       94512.40              NaN    No
# 521        1705.68            Fiber   NaN

# %%
df_clean["Contract_Type"].value_counts()
# Out:
# Contract_Type
# Month-to-Month    195
# One Year          174
# Two Year          162
# Name: count, dtype: int64

# %%
contract_mode = df_clean["Contract_Type"].mode()[0]
contract_mode
# Out:
# 'Month-to-Month'

# %%
df_clean["Contract_Type"] = df_clean["Contract_Type"].fillna(contract_mode)

# %%
df_clean["Contract_Type"].isna().sum()
# Out:
# np.int64(0)

# %%
df_clean["Contract_Type"].value_counts()
# Out:
# Contract_Type
# Month-to-Month    198
# One Year          174
# Two Year          162
# Name: count, dtype: int64

# %%
df_clean["Payment_Method"].isna().sum()
# Out:
# np.int64(15)

# %%
df_clean[df_clean["Payment_Method"].isna()][
    ["Customer_ID", "Subscription_Type", "Contract_Type",
     "Monthly_Charges", "Total_Charges", "Churn"]
]
# Out:
#     Customer_ID Subscription_Type   Contract_Type  Monthly_Charges  \
# 8         C1008             Basic        Two Year          1200.00
# 106       C1106             Basic  Month-to-Month           858.13
# 161       C1161             Basic  Month-to-Month          1265.50
# 237       C1237           Premium  Month-to-Month          1481.37
# 282       C1282             Basic  Month-to-Month          2312.01
# 329       C1329           Premium  Month-to-Month           620.87
# 348       C1348             Basic        Two Year          2278.26
# 364       C1364             Basic        Two Year           513.93
# 370       C1370             Basic  Month-to-Month          1711.37
# 400       C1400             Basic        Two Year           377.24
# 436       C1436          Standard  Month-to-Month           379.70
# 437       C1437           Premium  Month-to-Month           873.54
# 471       C1471          Standard        One Year          1927.08
# ...

# %%
df_clean["Payment_Method"].value_counts()
# Out:
# Payment_Method
# Debit Card     110
# UPI            109
# Cash           103
# Credit Card     99
# Net Banking     98
# Name: count, dtype: int64

# %%
payment_mode = df_clean["Payment_Method"].mode()[0]
payment_mode
# Out:
# 'Debit Card'

# %%
df_clean["Payment_Method"] = df_clean["Payment_Method"].fillna(payment_mode)

# %%
df_clean["Payment_Method"].isna().sum()
# Out:
# np.int64(0)

# %%
df_clean["Payment_Method"].value_counts()
# Out:
# Payment_Method
# Debit Card     125
# UPI            109
# Cash           103
# Credit Card     99
# Net Banking     98
# Name: count, dtype: int64

# %%
df_clean["Internet_Service"].isna().sum()
# Out:
# np.int64(6)

# %%
df_clean[df_clean["Internet_Service"].isna()][
    ["Customer_ID", "Subscription_Type", "Contract_Type",
     "Monthly_Charges", "Total_Charges", "Tenure_Months", "Churn"]
]
# Out:
#     Customer_ID Subscription_Type   Contract_Type  Monthly_Charges  \
# 72        C1072           Premium        Two Year          1914.24
# 252       C1252             Basic  Month-to-Month          1633.30
# 272       C1272          Standard        One Year           859.43
# 419       C1419          Standard  Month-to-Month          1391.93
# 450       C1450             Basic        One Year           714.58
# 518       C1518           Premium        One Year          2473.81
#
#      Total_Charges  Tenure_Months Churn
# 72         3962.48            2.0   Yes
# 252       94512.40           58.0    No
# 272       59798.10           70.0    No
# 419       25357.74           18.0   Yes
# 450        7573.80           10.0    No
# 518        2618.81            1.0   Yes

# %%
df_clean["Internet_Service"].value_counts()
# Out:
# Internet_Service
# Fiber    140
# Cable    133
# DSL      129
# 5G       126
# Name: count, dtype: int64

# %%
internet_mode = df_clean["Internet_Service"].mode()[0]
internet_mode
# Out:
# 'Fiber'

# %%
df_clean["Internet_Service"] = df_clean["Internet_Service"].fillna(internet_mode)

# %%
df_clean["Internet_Service"].isna().sum()
# Out:
# np.int64(0)

# %%
df_clean["Internet_Service"].value_counts()
# Out:
# Internet_Service
# Fiber    146
# Cable    133
# DSL      129
# 5G       126
# Name: count, dtype: int64

# %%
df_clean["Senior_Citizen"].isna().sum()
# Out:
# np.int64(7)

# %%
df_clean[df_clean["Senior_Citizen"].isna()][
    ["Customer_ID", "Age", "Gender", "Subscription_Type",
     "Contract_Type", "Churn"]
]
# Out:
#     Customer_ID   Age  Gender Subscription_Type   Contract_Type Churn
# 73        C1073  53.0  Female           Premium  Month-to-Month    No
# 160       C1160  67.0    Male           Premium        Two Year   Yes
# 252       C1252  46.0    Male             Basic  Month-to-Month    No
# 254       C1254  51.0  Female             Basic  Month-to-Month    No
# 432       C1432  64.0    Male          Standard  Month-to-Month   Yes
# 474       C1474  45.0  Female          Standard  Month-to-Month    No
# 522       C1522  49.0  Female           Premium  Month-to-Month   Yes

# %%
df_clean["Senior_Citizen"].value_counts()
# Out:
# Senior_Citizen
# No     424
# Yes    103
# Name: count, dtype: int64

# %%
senior_mode = df_clean["Senior_Citizen"].mode()[0]
senior_mode
# Out:
# 'No'

# %%
df_clean["Senior_Citizen"] = df_clean["Senior_Citizen"].fillna(senior_mode)

# %%
df_clean["Senior_Citizen"].isna().sum()
# Out:
# np.int64(0)

# %%
df_clean["Senior_Citizen"].value_counts()
# Out:
# Senior_Citizen
# No     431
# Yes    103
# Name: count, dtype: int64

# %%
df_clean[df_clean["Dependents"].isna()][
    ["Customer_ID", "Age", "Gender",
     "Subscription_Type", "Contract_Type",
     "Senior_Citizen", "Churn"]
]
# Out:
#     Customer_ID   Age  Gender Subscription_Type Contract_Type Senior_Citizen  \
# 12        C1012  35.0  Female             Basic      One Year             No
# 518       C1518  47.0    Male           Premium      One Year             No
#
#     Churn
# 12    Yes
# 518   Yes

# %%
df_clean["Dependents"].value_counts()
# Out:
# Dependents
# No     269
# Yes    263
# Name: count, dtype: int64

# %%
dependents_mode = df_clean["Dependents"].mode()[0]
dependents_mode
# Out:
# 'No'

# %%
df_clean["Dependents"] = df_clean["Dependents"].fillna(dependents_mode)

# %%
df_clean["Dependents"].isna().sum()
# Out:
# np.int64(0)

# %%
df_clean["Dependents"].value_counts()
# Out:
# Dependents
# No     271
# Yes    263
# Name: count, dtype: int64

# %%
df_clean["Churn"].isna().sum()
# Out:
# np.int64(3)

# %%
df_clean[df_clean["Churn"].isna()][
    ["Customer_ID", "Age", "Gender", "Tenure_Months",
     "Subscription_Type", "Contract_Type",
     "Monthly_Charges", "Total_Charges"]
]
# Out:
#     Customer_ID   Age   Gender  Tenure_Months Subscription_Type  \
# 158       C1158  35.0   Female           48.0           Premium
# 513       C1513  41.0   Female           66.0             Basic
# 521       C1521  54.0  Unknown            1.0           Premium
#
#       Contract_Type  Monthly_Charges  Total_Charges
# 158  Month-to-Month           593.22       27997.56
# 513  Month-to-Month          2491.79      164476.14
# 521  Month-to-Month          1666.22        1705.68

# %%
df_clean = df_clean.dropna(subset=["Churn"])

# %%
df_clean["Churn"].isna().sum()
# Out:
# np.int64(0)

# %%
df_clean.isna().sum()
# Out:
# Customer_ID              0
# Customer_Name            0
# Gender                   0
# Age                      0
# State                    0
# City                     0
# Tenure_Months            0
# Subscription_Type        0
# Monthly_Charges          0
# Total_Charges            0
# Contract_Type            0
# Payment_Method           0
# Internet_Service         0
# Tech_Support             0
# Senior_Citizen           0
# Dependents               0
# Churn                    0
# Last_Interaction_Date    3
# dtype: int64

# %%
df_clean.shape
# Out:
# (531, 18)

# %%
df_clean[df_clean["Last_Interaction_Date"].isna()][
    ["Customer_ID", "Last_Interaction_Date", "Churn", "Tenure_Months"]
]
# Out:
#     Customer_ID Last_Interaction_Date Churn  Tenure_Months
# 11        C1011                   NaT    No           69.0
# 382       C1382                   NaT    No           31.0
# 518       C1518                   NaT   Yes            1.0

# %%
df_clean["Last_Interaction_Date"].isna().sum()
# Out:
# np.int64(3)

# %%
df_clean["Last_Interaction_Date"].min(), df_clean["Last_Interaction_Date"].max()
# Out:
# (Timestamp('2025-01-01 00:00:00'), Timestamp('2026-07-04 00:00:00'))

# %%
df_clean["Last_Interaction_Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
# Done with all the cleaning , cheaking one last time

# %%
df_clean[df_clean["Age"] < 18][["Customer_ID", "Age"]]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Age]
# Index: []

# %%
df_clean[df_clean["Age"] > 100][["Customer_ID", "Age"]]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Age]
# Index: []

# %%
df_clean[df_clean["Tenure_Months"] <= 0][
    ["Customer_ID", "Tenure_Months"]
]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Tenure_Months]
# Index: []

# %%
df_clean[df_clean["Monthly_Charges"] < 0][
    ["Customer_ID", "Monthly_Charges"]
]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Monthly_Charges]
# Index: []

# %%
df_clean[df_clean["Total_Charges"] < 0][
    ["Customer_ID", "Total_Charges"]
]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Total_Charges]
# Index: []

# %%
df_clean["Gender"].value_counts()
# Out:
# Gender
# Female     268
# Male       260
# Unknown      3
# Name: count, dtype: int64

# %%
df_clean["Subscription_Type"].value_counts()
# Out:
# Subscription_Type
# Premium     192
# Basic       170
# Standard    169
# Name: count, dtype: int64

# %%
df_clean["Contract_Type"].value_counts()
# Out:
# Contract_Type
# Month-to-Month    195
# One Year          174
# Two Year          162
# Name: count, dtype: int64

# %%
df_clean["Contract_Type"].value_counts()
# Out:
# Contract_Type
# Month-to-Month    195
# One Year          174
# Two Year          162
# Name: count, dtype: int64

# %%
df_clean["Payment_Method"].value_counts()
# Out:
# Payment_Method
# Debit Card     124
# UPI            108
# Cash           103
# Credit Card     99
# Net Banking     97
# Name: count, dtype: int64

# %%
df_clean["Internet_Service"].value_counts()
# Out:
# Internet_Service
# Fiber    144
# Cable    132
# DSL      129
# 5G       126
# Name: count, dtype: int64

# %%
df_clean["Tech_Support"].value_counts()
# Out:
# Tech_Support
# No     273
# Yes    258
# Name: count, dtype: int64

# %%
df_clean["Senior_Citizen"].value_counts()
# Out:
# Senior_Citizen
# No     428
# Yes    103
# Name: count, dtype: int64

# %%
df_clean["Dependents"].value_counts()
# Out:
# Dependents
# No     270
# Yes    261
# Name: count, dtype: int64

# %%
df_clean["Churn"].value_counts()
# Out:
# Churn
# No     404
# Yes    127
# Name: count, dtype: int64

# %%
df_clean["Customer_ID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_clean["Customer_ID"].nunique()
# Out:
# 531

# %%
df_clean.shape
# Out:
# (531, 18)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 531 entries, 0 to 541
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            531 non-null    object
#  1   Customer_Name          531 non-null    object
#  2   Gender                 531 non-null    object
#  3   Age                    531 non-null    float64
#  4   State                  531 non-null    object
#  5   City                   531 non-null    object
#  6   Tenure_Months          531 non-null    float64
#  7   Subscription_Type      531 non-null    object
#  8   Monthly_Charges        531 non-null    float64
#  9   Total_Charges          531 non-null    float64
#  10  Contract_Type          531 non-null    object
#  11  Payment_Method         531 non-null    object
#  12  Internet_Service       531 non-null    object
#  13  Tech_Support           531 non-null    object
# ...

# %%
# Exporting clean data file

# %%
# df_clean.to_excel('clean_data.xlsx', index=False)
